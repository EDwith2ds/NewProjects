# %% [markdown]
# <h2 align='center'>ABOUT DATASET</h2>
#
# 570 cancer cells and 30 features to determine whether the cancer cells in our data are benign or malignant<br>
# Our cancer data contains 2 types of cancers: **1. benign cancer (B) and 2. malignant cancer(M).**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

df =  pd.read_csv(r"C:\Users\KingED\Documents\PracticeRepo-main\Cancer-cells-project-main\Cancer_Data.csv", index_col=0)
df
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# id
# 842302           M        17.99         10.38          122.80    1001.00  \
# 842517           M        20.57         17.77          132.90    1326.00
# 84300903         M        19.69         21.25          130.00    1203.00
# 84348301         M        11.42         20.38           77.58     386.10
# 84358402         M        20.29         14.34          135.10    1297.00
# ...            ...          ...           ...             ...        ...
# 926424           M        21.56         22.39          142.00    1479.00
# 926682           M        20.13         28.25          131.20    1261.00
# 926954           M        16.60         28.08          108.30     858.10
# 927241           M        20.60         29.33          140.10    1265.00
# 92751            B         7.76         24.54           47.92     181.00
#
#           smoothness_mean  compactness_mean  concavity_mean
# id
# ...
